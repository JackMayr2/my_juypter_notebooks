# %%
import sklearn as sk
import pandas as pd
import sklearn.model_selection
from IPython.display import display
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/Users/jackmayr/PycharmProjects/my_juypter_notebooks/csc_395/data/nasa.csv')
display(df)
# Out:
#       Neo Reference ID     Name  Absolute Magnitude  Est Dia in KM(min)  \
# 0              3703080  3703080              21.600            0.127220
# 1              3723955  3723955              21.300            0.146068
# 2              2446862  2446862              20.300            0.231502
# 3              3092506  3092506              27.400            0.008801
# 4              3514799  3514799              21.600            0.127220
# ...                ...      ...                 ...                 ...
# 4682           3759007  3759007              23.900            0.044112
# 4683           3759295  3759295              28.200            0.006089
# 4684           3759714  3759714              22.700            0.076658
# 4685           3759720  3759720              21.800            0.116026
# 4686           3772978  3772978              19.109            0.400641
#
#       Est Dia in KM(max)  Est Dia in M(min)  Est Dia in M(max)  \
# ...

# %%
plt.plot(df['Absolute Magnitude'], df['Orbital Period'])

# %%
plt.scatter(df['Absolute Magnitude'], df['Orbital Period'])

# %%
X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(df, 0.3, 0.7)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(df, 0.3, 0.7)
#
# File ~/PycharmProjects/my_juypter_notebooks/venv/lib/python3.11/site-packages/sklearn/model_selection/_split.py:2559, in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2556 if n_arrays == 0:
#    2557     raise ValueError("At least one array required as input")
# -> 2559 arrays = indexable(*arrays)
#    2561 n_samples = _num_samples(arrays[0])
#    2562 n_train, n_test = _validate_shuffle_split(
#    2563     n_samples, test_size, train_size, default_test_size=0.25
#    2564 )
#
# File ~/PycharmProjects/my_juypter_notebooks/venv/lib/python3.11/site-packages/sklearn/utils/validation.py:443, in indexable(*iterables)
#     424 """Make arrays indexable for cross-validation.
# ...
